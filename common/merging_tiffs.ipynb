# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
#run from repo root...
os.chdir(r"C:/Users/jamed\Documents/repos/lidar_2/LidarClassifcationForFloodModelling")

# %%
from common.data_managment import merge_tiffs

in_dir = "C:\\Users\\jamed\\Documents\\unprocessed_data\\tiffs"
out_dir = "C:\\Users\\jamed\\Documents\\repos\\lidar_2\\LidarClassifcationForFloodModelling\\data"
out_name = "COMBINED_STANDARDISED_TEST"

merge_tiffs(target_dir = in_dir, save_dir=out_dir, out_name=out_name)
# Out:
# WindowsPath('C:/Users/jamed/Documents/repos/lidar_2/LidarClassifcationForFloodModelling/data/COMBINED_STANDARDISED_TEST.tif')
