# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
#Set root correctly...
os.chdir(r"C:\Users\jamed\Documents\repos\LidarClassifcationForFloodModelling")

# %%
from RandLANetImplementation.data import load_pos_neg_dfs, build_lidar_tensor, get_train_test_sets
las_data = load_pos_neg_dfs()
las_tensor = build_lidar_tensor(las_data)

# %%
train, test = get_train_test_sets(las_tensor)

# %%
from RandLANetImplementation.data import get_folds
folds = get_folds(test, 4)

# %%
from RandLANetImplementation.gpt_vibe_code_trash_quarentine import visualize_windows_from_tensor
visualize_windows_from_tensor(test,folds=folds, fx=0,fy=1)

# %%
windows[0][:5]
